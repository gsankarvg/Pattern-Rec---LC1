# %%
import cv2
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
import pandas as pd

# %%
img = cv2.imread('shapes.jpg')
plt.imshow(img)

# %%
img = cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
plt.imshow(img)

# %% [markdown]
# reshaped image from (M, N ,3) to (M * N, 3)

# %%
img=img.reshape((-1, 3))

# %%
kmeans=KMeans(n_clusters=5)
s=kmeans.fit(img)
